# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df=pd.read_csv('Startups1.csv')
df
# Out:
#      Unnamed: 0                Company       City  Starting Year  \
# 0             0          Urban Company    Gurgaon           2014
# 1             1              Classplus      Noida           2018
# 2             2                  Paytm      Noida           2010
# 3             3                   Apna     Mumbai           2019
# 4             4               Razorpay  Bengaluru           2014
# ..          ...                    ...        ...            ...
# 295         295               SafexPay      Thane           2017
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 298         298               CredFlow  New Delhi           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Company       City  Starting Year  \
# 0           0  Urban Company    Gurgaon           2014
# 1           1      Classplus      Noida           2018
# 2           2          Paytm      Noida           2010
# 3           3           Apna     Mumbai           2019
# 4           4       Razorpay  Bengaluru           2014
#
#                                             Founders  \
# 0  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                Akshay Khanna, Vijay Shekhar Sharma
# 3                                      Nirmit Parikh
# 4                     Harshil Mathur, Shashank Kumar
#
#                                           Industries  \
# 0  Apps, Home Services, Marketplace, Service Indu...
# 1  B2B, E-Learning, EdTech, Education, Mobile App...
# 2  E-Commerce, Finance, Financial Services, Inter...
# 3  Employment, Human Resources, Recruiting, Staff...
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0                Company       City  Starting Year  \
# 295         295               SafexPay      Thane           2017
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 298         298               CredFlow  New Delhi           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 295                                         Ravi Gupta
# 296  Deepak Choudhary, Karanvir Singh Shekhawat, Ut...
# 297        Sachin Gautam, Sudhanshu Rai, Sumit Sheoran
# 298                                     Kunal Aggarwal
# 299                                     Swapnil Saurav
#
#                                             Industries  \
# 295                                  FinTech, Payments
# 296    E-Learning, EdTech, Education, Skill Assessment
# 297  Agriculture, AgTech, Artificial Intelligence, ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           300 non-null    int64
#  1   Company              300 non-null    object
#  2   City                 300 non-null    object
#  3   Starting Year        300 non-null    int64
#  4   Founders             300 non-null    object
#  5   Industries           300 non-null    object
#  6   Description          300 non-null    object
#  7   No. of Employees     300 non-null    object
#  8   Funding Amount in $  300 non-null    int64
#  9   Funding Round        300 non-null    int64
#  10  No. of Investors     300 non-null    int64
# dtypes: int64(5), object(6)
# memory usage: 25.9+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  Starting Year  Funding Amount in $  Funding Round  \
# count  300.000000     300.000000         3.000000e+02     300.000000
# mean   149.500000    2013.393333         3.148655e+08       5.986667
# std     86.746758       5.139390         1.628802e+09       4.239465
# min      0.000000    1984.000000         0.000000e+00       0.000000
# 25%     74.750000    2012.000000         1.428738e+07       3.000000
# 50%    149.500000    2015.000000         4.108773e+07       5.000000
# 75%    224.250000    2016.000000         1.319438e+08       7.000000
# max    299.000000    2020.000000         2.476762e+10      25.000000
#
#        No. of Investors
# count        300.000000
# mean          10.550000
# std            7.530151
# min            0.000000
# 25%            5.000000
# 50%            9.000000
# 75%           14.000000
# max           45.000000

# %%
df.isna().sum()
# Out:
# Unnamed: 0             0
# Company                0
# City                   0
# Starting Year          0
# Founders               0
# Industries             0
# Description            0
# No. of Employees       0
# Funding Amount in $    0
# Funding Round          0
# No. of Investors       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include='object')
# Out:
#               Company       City       Founders  \
# count             300        300            300
# unique            300         24            288
# top     Urban Company  Bengaluru  Not Available
# freq                1        123              9
#
#                            Industries  \
# count                             300
# unique                            290
# top     E-Learning, EdTech, Education
# freq                                5
#
#                                               Description No. of Employees
# count                                                 300              300
# unique                                                300               10
# top     Urban is a marketplace for independent contrac...          101-250
# freq                                                    1               63

# %%
corr=df.select_dtypes('number').corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df['Industries'].str.split(',' , expand=True)
# Out:
#                          0                    1                         2  \
# 0                     Apps        Home Services               Marketplace
# 1                      B2B           E-Learning                    EdTech
# 2               E-Commerce              Finance        Financial Services
# 3               Employment      Human Resources                Recruiting
# 4       Financial Services              FinTech                  Payments
# ..                     ...                  ...                       ...
# 295                FinTech             Payments                      None
# 296             E-Learning               EdTech                 Education
# 297            Agriculture               AgTech   Artificial Intelligence
# 298                 Credit   Financial Services                      None
# 299  Digital Entertainment       Fantasy Sports                    Sports
#
#                        3             4                 5          6     7  \
# ...

# %%
df
# Out:
#      Unnamed: 0                Company       City  Starting Year  \
# 0             0          Urban Company    Gurgaon           2014
# 1             1              Classplus      Noida           2018
# 2             2                  Paytm      Noida           2010
# 3             3                   Apna     Mumbai           2019
# 4             4               Razorpay  Bengaluru           2014
# ..          ...                    ...        ...            ...
# 295         295               SafexPay      Thane           2017
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 298         298               CredFlow  New Delhi           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# ...

# %%
df.drop(columns=['Unnamed: 0','Description'],inplace=True)

# %%
df
# Out:
#                    Company       City  Starting Year  \
# 0            Urban Company    Gurgaon           2014
# 1                Classplus      Noida           2018
# 2                    Paytm      Noida           2010
# 3                     Apna     Mumbai           2019
# 4                 Razorpay  Bengaluru           2014
# ..                     ...        ...            ...
# 295               SafexPay      Thane           2017
# 296               Pariksha       Pune           2015
# 297                  Fyllo  Bengaluru           2019
# 298               CredFlow  New Delhi           2019
# 299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                  Akshay Khanna, Vijay Shekhar Sharma
# 3                                        Nirmit Parikh
# ...

# %%
df['Ageofcompany']=df['Starting Year'].apply(lambda x: datetime.now().year-x)
df['Ageofcompany']
# Out:
# 0      10
# 1       6
# 2      14
# 3       5
# 4      10
#        ..
# 295     7
# 296     9
# 297     5
# 298     5
# 299     8
# Name: Ageofcompany, Length: 300, dtype: int64

# %%
df.columns
# Out:
# Index(['Company', 'City', 'Starting Year', 'Founders', 'Industries',
#        'No. of Employees', 'Funding Amount in $', 'Funding Round',
#        'No. of Investors', 'Ageofcompany'],
#       dtype='object')

# %%
df.head()
# Out:
#          Company       City  Starting Year  \
# 0  Urban Company    Gurgaon           2014
# 1      Classplus      Noida           2018
# 2          Paytm      Noida           2010
# 3           Apna     Mumbai           2019
# 4       Razorpay  Bengaluru           2014
#
#                                             Founders  \
# 0  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                Akshay Khanna, Vijay Shekhar Sharma
# 3                                      Nirmit Parikh
# 4                     Harshil Mathur, Shashank Kumar
#
#                                           Industries No. of Employees  \
# 0  Apps, Home Services, Marketplace, Service Indu...        1001-5000
# 1  B2B, E-Learning, EdTech, Education, Mobile App...          101-250
# 2  E-Commerce, Finance, Financial Services, Inter...         501-1000
# 3  Employment, Human Resources, Recruiting, Staff...          101-250
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              300 non-null    object
#  1   City                 300 non-null    object
#  2   Starting Year        300 non-null    int64
#  3   Founders             300 non-null    object
#  4   Industries           300 non-null    object
#  5   No. of Employees     300 non-null    object
#  6   Funding Amount in $  300 non-null    int64
#  7   Funding Round        300 non-null    int64
#  8   No. of Investors     300 non-null    int64
#  9   Ageofcompany         300 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 23.6+ KB

# %%
df["Industries_type_1"]= df['Industries'].str.split(",", expand = True)[0]

# %%
df["Industries_type_2"]= df['Industries'].str.split(",", expand = True)[1]

# %%
df["Industries_type_2"].isna().sum()
# Out:
# 10

# %%
df['Industries_type_2'].fillna('N/A', inplace = True)

# %%
df['Ageofcompany'].hist(bins = 20)
# Out:
# <Axes: >

# %%
sns.histplot(df['Ageofcompany'], bins = 10)
# Out:
# <Axes: xlabel='Ageofcompany', ylabel='Count'>

# %%
pd.cut(x = df.Ageofcompany,bins= [0,5,15,np.inf], labels= ['early_startup', "mid_level_startup", "old_company"])
# Out:
# 0      mid_level_startup
# 1      mid_level_startup
# 2      mid_level_startup
# 3          early_startup
# 4      mid_level_startup
#              ...
# 295    mid_level_startup
# 296    mid_level_startup
# 297        early_startup
# 298        early_startup
# 299    mid_level_startup
# Name: Ageofcompany, Length: 300, dtype: category
# Categories (3, object): ['early_startup' < 'mid_level_startup' < 'old_company']

# %%
df['agecategory'] = pd.cut(x = df.Ageofcompany,bins= [0,5,15,np.inf], labels= ['early_startup', "mid_level_startup", "old_company"])

# %%
df.head()
# Out:
#          Company       City  Starting Year  \
# 0  Urban Company    Gurgaon           2014
# 1      Classplus      Noida           2018
# 2          Paytm      Noida           2010
# 3           Apna     Mumbai           2019
# 4       Razorpay  Bengaluru           2014
#
#                                             Founders  \
# 0  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                Akshay Khanna, Vijay Shekhar Sharma
# 3                                      Nirmit Parikh
# 4                     Harshil Mathur, Shashank Kumar
#
#                                           Industries No. of Employees  \
# 0  Apps, Home Services, Marketplace, Service Indu...        1001-5000
# 1  B2B, E-Learning, EdTech, Education, Mobile App...          101-250
# 2  E-Commerce, Finance, Financial Services, Inter...         501-1000
# 3  Employment, Human Resources, Recruiting, Staff...          101-250
# ...

# %%
plt.figure(figsize=(19,3))
sns.countplot(x='Starting Year',data=df,palette="twilight_shifted", edgecolor = 'black')
plt.title('Count of Records by Starting Year', fontdict={'fontsize':20}, bbox={'facecolor': 'lightblue'})
# Out:
# Text(0.5, 1.0, 'Count of Records by Starting Year')

# %%
plt.figure(figsize=(19,3))
sns.countplot(x='Starting Year', data=df)
plt.title('Distribution Over year',bbox={'facecolor':'white', 'alpha':0.5})
plt.show()

# %%
from wordcloud import WordCloud

# %%
word=df['City']

# %%
text=" ".join(word)

# %%
wordcloud = WordCloud(width = 800, height = 400, background_color="white").generate(text)

# %%
wordcloud = WordCloud(width = 800,height = 400, background_color ='white').generate(text)

# %%
plt.figure(figsize=(10,6))

plt.imshow(wordcloud)

# %%
Founders=df.groupby('Founders')['Founders'].size().rename('Count').reset_index()
Top5=Founders.sort_values(by='Count',ascending=False).head(5)
plt.pie(Top5['Count'],labels=Top5['Founders'],autopct="%1.2f%%",explode=[0,0.1,0,0,0])
plt.legend(loc='center', bbox_to_anchor=(2.5, 0.5))
plt.title('Top 5 Founders')
plt.show()

# %%
x= df['Founders'].value_counts().iloc[1:5]
explode = (0, 0.1, 0.05, 0.1)
plt.figure(figsize=(6, 6))
plt.pie(x, labels=x.index, explode=explode, autopct='%1.1f%%', shadow= True, wedgeprops={"width":0.6}, colors=sns.color_palette("twilight_shifted"))
plt.title('Top 4 Founders',fontdict={'fontsize':20}, bbox={'facecolor': 'lightblue'})
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='No. of Employees', data=df, palette="twilight_shifted", edgecolor = 'black')
plt.title('Count of Records by Starting Year', fontdict={'fontsize':20}, bbox={'facecolor': 'lightblue'})
# Out:
# Text(0.5, 1.0, 'Count of Records by Starting Year')

# %%
df
# Out:
#                    Company       City  Starting Year  \
# 0            Urban Company    Gurgaon           2014
# 1                Classplus      Noida           2018
# 2                    Paytm      Noida           2010
# 3                     Apna     Mumbai           2019
# 4                 Razorpay  Bengaluru           2014
# ..                     ...        ...            ...
# 295               SafexPay      Thane           2017
# 296               Pariksha       Pune           2015
# 297                  Fyllo  Bengaluru           2019
# 298               CredFlow  New Delhi           2019
# 299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                  Akshay Khanna, Vijay Shekhar Sharma
# 3                                        Nirmit Parikh
# ...

# %%
df.groupby(['Starting Year','Company'],as_index=False)['Funding Amount in $'].max().sort_values(by='Funding Amount in $',ascending=False).head(10).style.background_gradient(cmap='twilight_shifted')
# Out:
# <style type="text/css">
# #T_4b48b_row0_col0, #T_4b48b_row4_col0 {
#   background-color: #bc6b59;
#   color: #f1f1f1;
# }
# #T_4b48b_row0_col2, #T_4b48b_row8_col0 {
#   background-color: #2f1436;
#   color: #f1f1f1;
# }
# #T_4b48b_row1_col0 {
#   background-color: #e2d9e2;
#   color: #000000;
# }
# #T_4b48b_row1_col2 {
#   background-color: #6f93c0;
#   color: #f1f1f1;
# }
# #T_4b48b_row2_col0 {
#   background-color: #bccbd1;
#   color: #000000;
# }
# #T_4b48b_row2_col2 {
#   background-color: #5e53ae;
#   color: #f1f1f1;
# }
# #T_4b48b_row3_col0, #T_4b48b_row9_col2 {
#   background-color: #301437;
#   color: #f1f1f1;
# }
# #T_4b48b_row3_col2 {
#   background-color: #551f7f;
#   color: #f1f1f1;
# }
# #T_4b48b_row4_col2 {
#   background-color: #4b1668;
#   color: #f1f1f1;
# }
# #T_4b48b_row5_col0 {
#   background-color: #7f2350;
#   color: #f1f1f1;
# }
# #T_4b48b_row5_col2 {
#   background-color: #44135a;
#   color: #f1f1f1;
# }
# #T_4b48b_row6_col0, #T_4b48b_row7_col0 {
# ...

# %%
df1=df.groupby(['City'],as_index=False)['Funding Amount in $'].sum().sort_values(by='Funding Amount in $',ascending=False).head(10)
df1
# Out:
#           City  Funding Amount in $
# 14      Mumbai          36055016291
# 3    Bengaluru          26207212825
# 7      Gurgaon          15827429512
# 16       Noida           6134005051
# 13  Kormangala           3836092733
# 15   New Delhi           1888117254
# 4      Chennai            849120965
# 19        Pune            659265509
# 6    Faridabad            638829632
# 9    Hyderabad            557189029

# %%
plt.figure(figsize=(14,8))
sns.barplot(x= 'City',y='Funding Amount in $',data=df1)
# Out:
# <Axes: xlabel='City', ylabel='Funding Amount in $'>
